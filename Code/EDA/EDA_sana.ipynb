# %%
import numpy as np
import pandas as pd
import os 

from pandas.plotting import scatter_matrix

import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %%
print("Current directory :", os.getcwd())

# Changing the CWD
os.chdir('C:\\Users\\user\\OneDrive\\Desktop\\Github\\Predictive-Maintenance\\Datasets')

print("Changed directory :",os.getcwd())
# Out:
# Current directory : C:\Users\user\OneDrive\Desktop\Github\Predictive-Maintenance\Code\EDA
# Changed directory : C:\Users\user\OneDrive\Desktop\Github\Predictive-Maintenance\Datasets

# %%
#load the datasets

df_train_1 = pd.read_csv('train_FD001.csv')
df_test_1 = pd.read_csv('test_FD001.csv')

# %%
#Explore the dataset
df_train_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20631 entries, 0 to 20630
# Data columns (total 27 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Engine            20631 non-null  int64
#  1   Cycles            20631 non-null  int64
#  2   Sensor1           20631 non-null  float64
#  3   Sensor2           20631 non-null  float64
#  4   Sensor3           20631 non-null  float64
#  5   Sensor4           20631 non-null  float64
#  6   Sensor5           20631 non-null  float64
#  7   Sensor6           20631 non-null  float64
#  8   Sensor7           20631 non-null  float64
#  9   Sensor8           20631 non-null  float64
#  10  Sensor9           20631 non-null  float64
#  11  Sensor10          20631 non-null  float64
#  12  Sensor11          20631 non-null  float64
#  13  Sensor12          20631 non-null  float64
#  14  Sensor13          20631 non-null  float64
#  15  Sensor14          20631 non-null  float64
# ...

# %%
df_train_1.head()
# Out:
#    Engine  Cycles  Sensor1  Sensor2  Sensor3  Sensor4  Sensor5  Sensor6  \
# 0       1       1  -0.0007  -0.0004    100.0   518.67   641.82  1589.70
# 1       1       2   0.0019  -0.0003    100.0   518.67   642.15  1591.82
# 2       1       3  -0.0043   0.0003    100.0   518.67   642.35  1587.99
# 3       1       4   0.0007   0.0000    100.0   518.67   642.35  1582.79
# 4       1       5  -0.0019  -0.0002    100.0   518.67   642.37  1582.85
#
#    Sensor7  Sensor8  ...  Sensor16  Sensor17  Sensor18  Sensor19  Sensor20  \
# 0  1400.60    14.62  ...   2388.02   8138.62    8.4195      0.03       392
# 1  1403.14    14.62  ...   2388.07   8131.49    8.4318      0.03       392
# 2  1404.20    14.62  ...   2388.03   8133.23    8.4178      0.03       390
# 3  1401.87    14.62  ...   2388.08   8133.83    8.3682      0.03       392
# 4  1406.22    14.62  ...   2388.04   8133.80    8.4294      0.03       393
#
#    Sensor21  Sensor22  Sensor23  Sensor24  Remaining Cycles
# ...

# %%
df_train_1.shape
# Out:
# (20631, 27)

# %%
df_train_1.describe().T
# Out:
#                     count         mean           std        min        25%  \
# Engine            20631.0    51.506568  2.922763e+01     1.0000    26.0000
# Cycles            20631.0   108.807862  6.888099e+01     1.0000    52.0000
# Sensor1           20631.0    -0.000009  2.187313e-03    -0.0087    -0.0015
# Sensor2           20631.0     0.000002  2.930621e-04    -0.0006    -0.0002
# Sensor3           20631.0   100.000000  0.000000e+00   100.0000   100.0000
# Sensor4           20631.0   518.670000  6.537152e-11   518.6700   518.6700
# Sensor5           20631.0   642.680934  5.000533e-01   641.2100   642.3250
# Sensor6           20631.0  1590.523119  6.131150e+00  1571.0400  1586.2600
# Sensor7           20631.0  1408.933782  9.000605e+00  1382.2500  1402.3600
# Sensor8           20631.0    14.620000  3.394700e-12    14.6200    14.6200
# Sensor9           20631.0    21.609803  1.388985e-03    21.6000    21.6100
# ...

# %% [markdown]
# ### Inference :
# It looks like no outlier looking as of now

# %% [markdown]
# ### Missing Values

# %%
df_train_1.isnull().sum()
# Out:
# Engine              0
# Cycles              0
# Sensor1             0
# Sensor2             0
# Sensor3             0
# Sensor4             0
# Sensor5             0
# Sensor6             0
# Sensor7             0
# Sensor8             0
# Sensor9             0
# Sensor10            0
# Sensor11            0
# Sensor12            0
# Sensor13            0
# Sensor14            0
# Sensor15            0
# Sensor16            0
# Sensor17            0
# Sensor18            0
# Sensor19            0
# Sensor20            0
# Sensor21            0
# Sensor22            0
# Sensor23            0
# Sensor24            0
# Remaining Cycles    0
# dtype: int64

# %% [markdown]
# ### Inference :
# No Missing values

# %%
df_train_1.dtypes
# Out:
# Engine                int64
# Cycles                int64
# Sensor1             float64
# Sensor2             float64
# Sensor3             float64
# Sensor4             float64
# Sensor5             float64
# Sensor6             float64
# Sensor7             float64
# Sensor8             float64
# Sensor9             float64
# Sensor10            float64
# Sensor11            float64
# Sensor12            float64
# Sensor13            float64
# Sensor14            float64
# Sensor15            float64
# Sensor16            float64
# Sensor17            float64
# Sensor18            float64
# Sensor19            float64
# Sensor20              int64
# Sensor21              int64
# Sensor22            float64
# Sensor23            float64
# Sensor24            float64
# Remaining Cycles      int64
# dtype: object

# %% [markdown]
# ### Inference :
# No Categorical Values

# %% [markdown]
# ## Correlation and Outliers

# %%
_ = scatter_matrix(df_train_1.iloc[:,0:], figsize=(12, 8))

# %%
# Show a correlation on a heat map.
plt.subplots(figsize=(20,20))
dataplot = sns.heatmap(df_train_1.corr(), cmap="YlGnBu", annot=True)
# displaying heatmap
plt.show()

# %% [markdown]
# ### Inference:
# The white color here shows no correlation at all
