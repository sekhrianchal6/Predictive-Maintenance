# %%
import pandas as pd
# Out:
# C:\Users\jyosn\AppData\Local\Temp\ipykernel_16380\4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df_train=pd.read_csv("C:\\Users\\jyosn\\Documents\\GitHub\\Predictive-Maintenance\\Datasets\\train_FD001.csv")
df_train.drop(columns=['Sensor3','Sensor4','Sensor8','Sensor13','Sensor19','Sensor21','Sensor22'],inplace=True)

# %%
df_train.head()
# Out:
#    Engine  Cycles  Sensor1  Sensor2  Sensor5  Sensor6  Sensor7  Sensor9  \
# 0       1       1  -0.0007  -0.0004   641.82  1589.70  1400.60    21.61
# 1       1       2   0.0019  -0.0003   642.15  1591.82  1403.14    21.61
# 2       1       3  -0.0043   0.0003   642.35  1587.99  1404.20    21.61
# 3       1       4   0.0007   0.0000   642.35  1582.79  1401.87    21.61
# 4       1       5  -0.0019  -0.0002   642.37  1582.85  1406.22    21.61
#
#    Sensor10  Sensor11  Sensor12  Sensor14  Sensor15  Sensor16  Sensor17  \
# 0    554.36   2388.06   9046.19     47.47    521.66   2388.02   8138.62
# 1    553.75   2388.04   9044.07     47.49    522.28   2388.07   8131.49
# 2    554.26   2388.08   9052.94     47.27    522.42   2388.03   8133.23
# 3    554.45   2388.11   9049.48     47.13    522.86   2388.08   8133.83
# 4    554.00   2388.06   9055.15     47.28    522.19   2388.04   8133.80
#
#    Sensor18  Sensor20  Sensor23  Sensor24  Remaining Cycles
# ...

# %%
##lagging

df_train["lag1"]=df_train['Remaining Cycles'].shift(10)
df_train.head()
df_train["lag2"]=df_train['Remaining Cycles'].shift(20)
df_train["lag3"]=df_train['Remaining Cycles'].shift(30)
df_train["lag4"]=df_train['Remaining Cycles'].shift(40)
df_train["lag5"]=df_train['Remaining Cycles'].shift(50)
df_train.head(20)
# Out:
#     Engine  Cycles  Sensor1  Sensor2  Sensor5  Sensor6  Sensor7  Sensor9  \
# 0        1       1  -0.0007  -0.0004   641.82  1589.70  1400.60    21.61
# 1        1       2   0.0019  -0.0003   642.15  1591.82  1403.14    21.61
# 2        1       3  -0.0043   0.0003   642.35  1587.99  1404.20    21.61
# 3        1       4   0.0007   0.0000   642.35  1582.79  1401.87    21.61
# 4        1       5  -0.0019  -0.0002   642.37  1582.85  1406.22    21.61
# 5        1       6  -0.0043  -0.0001   642.10  1584.47  1398.37    21.61
# 6        1       7   0.0010   0.0001   642.48  1592.32  1397.77    21.61
# 7        1       8  -0.0034   0.0003   642.56  1582.96  1400.97    21.61
# 8        1       9   0.0008   0.0001   642.12  1590.98  1394.80    21.61
# 9        1      10  -0.0033   0.0001   641.71  1591.24  1400.46    21.61
# 10       1      11   0.0018  -0.0003   642.28  1581.75  1400.64    21.61
# 11       1      12   0.0016   0.0002   642.06  1583.41  1400.15    21.61
# ...
